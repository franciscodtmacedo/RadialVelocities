# %%
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=(20,10)

data = fits.getdata("r.ESPRE.2022-02-13T00_35_11.355_S1D_A.fits")
wave = data["wavelength_air"]
flux = data["flux"]

plt.plot(wave,flux)

# %%
N=len(wave)
matrix=np.zeros([N,2])
matrix[:,0]=wave
matrix[:,1]=flux

# %%
np.savetxt('espresso_data.txt',matrix,newline='\n')
